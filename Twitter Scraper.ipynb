# %%
import pandas as pd
import twint
import nest_asyncio
nest_asyncio.apply()
import datetime
import time
import numpy as np

# %%
def twitter(query = None, start = None, end = None, limit = None, user = None):
    config = twint.Config()
    config.Limit = limit
    config.Search = query
    config.Pandas = True
    config.Hide_output = True
    config.Since = start
    config.Until = end
    config.Username = user
    twint.run.Search(config)
    df = twint.output.panda.Tweets_df
    df['date'] = pd.to_datetime(df['date'])
    return df

# %%
#example use case
SABIC = twitter(user = 'SABIC', limit = 10)

# %%
SABIC.shape
# Out:
# (100, 38)

# %%
SABIC.head()
# Out:
#                     id      conversation_id    created_at                date  \
# 0  1399642990302298113  1399642990302298113  1.622536e+12 2021-06-01 09:24:27
# 1  1399274447559827459  1399274447559827459  1.622448e+12 2021-05-31 09:00:00
# 2  1398957362417897474  1398957362417897474  1.622372e+12 2021-05-30 12:00:01
# 3  1398950392055074819  1398950392055074819  1.622371e+12 2021-05-30 11:32:19
# 4  1397896262264016897  1397896262264016897  1.622119e+12 2021-05-27 13:43:35
#
#   timezone place                                              tweet language  \
# 0    +0100        Which out of these is your favorite #sustainab...       en
# 1    +0100        Research excellence has played a large part in...       en
# 2    +0100        To enable students to innovate, create, delive...       en
# 3    +0100        On the #WorldMSDay, we stand in solidarity wit...       en
# 4    +0100        Through #SABIC Global Educational &amp; #Innov...       en
#
#                                             hashtags cashtags  ...  geo  \
# 0                                   [sustainability]       []  ...
# 1                      [chemistrythatmatters, sabic]       []  ...
# 2          [innovation, chemistrythatmatters, sabic]       []  ...
# 3  [worldmsday, msconnections, chemistrythatmatte...       []  ...
# 4  [sabic, innovation, education, chemistrythatma...       []  ...
#
#   source user_rt_id user_rt  retweet_id reply_to retweet_date translate  \
# 0                                             []
# 1                                             []
# 2                                             []
# 3                                             []
# 4                                             []
#
#   trans_src  trans_dest
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 38 columns]
